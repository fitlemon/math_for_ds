# %% [markdown]
# ✍Итак, начнём же наше погружение в линейную алгебру с фундаментального понятия этой науки —  **вектора**.
#
# На протяжении курса мы много раз встречались с этим термином. Например, мы часто говорили «вектор-столбец», когда работали с _DataFrame_, или «вектор параметров» в моделях линейной регрессии. Настало время посмотреть на эту терминологию с формальной точки зрения. Существует множество определений понятия «вектор» в зависимости от контекста.
#
# На уроках геометрии в школе вам рассказывали, что  **вектор**  — это отрезок, соединяющий две точки в пространстве и имеющий направление. Например, вектор  , представленный на рисунке ниже, соединяет две точки,  и . Направление вектора указывается от точки  к точке .
#
# ![](./vectors/image1.png)
#
# В строгом математическом смысле под  **вектором**  понимается часть некоторого векторного пространства с множеством различных свойств, но об этом мы поговорим чуть позже.
#
# В _Python_ тоже есть своё понятие вектора, например это одномерный _numpy_-массив или список из чисел.
#
# Давайте введём  **наиболее общее определение** , которое подойдёт ко всем случаям.
#
# **Вектор**  — это набор чисел, записанных в определённом порядке (в столбец или в строку).
#
# Вектор, состоящий из  координат, записывается следующим образом:
#
#  —вектор-строка
#
# или
#
#  —вектор-столбец
#
# **Примечание.**  Стрелка наверху  указывает на то, что переменная  является вектором. Однако нередко в литературе для краткости записи стрелку опускают и записывают просто . Мы будем придерживаться математического формализма и ставить стрелку для обозначения вектора.
#
# Давайте сразу рассмотрим  **пример из жизни**.
#
# Агентство недвижимости «Рай в шалаше» занимается сдачей жилья в аренду. Данные по объектам в одном районе Москвы за последний месяц представлены в таблице ниже.
#
# Столбцы этой таблицы мы можем рассмотреть в качестве векторов, получив информацию о каждой квартире по одному параметру, например по величине арендной платы (вектор ). Если взять в качестве векторов строки таблицы, то мы увидим срез всех параметров по одной квартире (вектор ).
#
# ![](./vectors/image2.png)
#
# Числа  называются ** **** координатами вектора **, а количество этих координат  называется ** размерностью вектора**.
#
# **Примечание.**  Векторы  и  из прошлого примера имели размерности .
#
# А
#
# **?**
#
# гентство недвижимости выставило за неделю несколько квартир площадью 33, 65, 50 и 45 кв. м. Сколько всего квартир выставлено за неделю? Какова площадь квартиры № 3?
#
# Решим нашу задачу с помощью векторного инструментария. Составим вектор ) из площадей квартир.
#
# Количество квартир равно размерности вектора . Размерность — количество координат: .
#
# Площадь третьей квартиры — это третья координата вектора:
#
# * * *
#
# Теперь рассмотрим, что представляет собой вектор в _Python_.
#
# Рассматриваем ту же самую задачу. Дан вектор . Необходимо найти его размерность и третью координату.
#
# | **1** | Вызываем библиотеку _numpy_, т. к. именно в ней удобнее всего работать с векторами.
# ```
# **import** numpy **as** np
# ```
#  |
# | --- | --- |
# | **2** | Задаём вектор  как одномерный массив _numpy_ с помощью функции np.array.
# ```
# s = np.array([33, 64, 50, 45])s## array([33, 64, 50, 45])
# ```
#  |
# | **3** | Находим третью координату.Помним, что в _Python_ массивы нумеруются с нуля, а не с единицы, поэтому для третьей квартиры нужен элемент массива с номером 2.
# ```
# s[2]## 50
# ```
#  |
# | **4** | Находим размерность вектора. За размерность отвечает функция len().
# ```
# len(s)## 4
# ```
#  |
#
# У вас, должно быть, возник вопрос: «Зачем так сложно?!» Зачем мы вводили векторы, их координаты и размерности, а потом даже писали программу, если и так понятно, что количество квартир — 4, а площадь третьей квартиры — .
#
# Представьте, что квартир не четыре, а несколько сотен, и вам нужно узнать их точное количество, а также получить параметры квартиры № 151. В таком случае математика будет работать точно так же, как и для случая из четырёх квартир. В этом и состоит прелесть математики: рассматривая частный простой случай, мы почти всегда можем быть уверены, что точно такая же логика сработает и в общем случае.
#
# **Примечание.**  Из описанного выше правила существуют исключения, однако они выходят за рамки нашего курса и используются в основном в приложениях теоретической физики.
#
#  —вектор очень большой размерности.
#
#  —количество квартир.
#
#  —площадь 151-й квартиры.
#
# В дальнейшем все примеры будут на простых числах для удобства вычислений, наглядности и экономии времени.  Однако важно понимать, что все операции, которые мы рассмотрим, в случаях большей размерности работают точно так же.
#
# ### Задание 2.1
#
# 0 points possible (ungraded)
#
# Дан вектор в _Python_ вида `t = np.array([12, 14, 17, 19, 24, 28, 31, 31, 27, 22, 17, 13])`, содержащий информацию о средней температуре воздуха (в градусах Цельсия) в Риме с января по декабрь включительно. Будем считать, что температура в январе — , то есть отсчёт индексов идёт с нуля.
#
#   **неверное**  утверждение:
#
#  —средняя температура воздуха в июне
#
#  —средняя температура воздуха в феврале
#
# верно
#
# Show answer
#
# Отправить
#
# Some problems have options such as save, reset, hints, or show answer. These options follow the Submit button.
#
# **\*ГЕОМЕТРИЧЕСКАЯ ИНТЕРПРЕТАЦИЯ ВЕКТОРА. ВЕКТОРНОЕ ПРОСТРАНСТВО**
#
# Рядом с линейной алгеброй всегда идёт наука под названием  **аналитическая геометрия**. Поэтому, говоря о векторах, нельзя не упомянуть о его геометрической интерпретации, чтобы создать целостное понимание. Геометрический смысл вектора поможет понять, что такое  **векторное пространство**.
#
# **Примечание.**  Приведённая геометрическая интерпретация справедлива как для векторов, записанных в строку, так и для векторов, записанных в столбец.
#
# Пусть у нас есть какой-то вектор  размерности .
#
# Выберем прямоугольную систему координат , на которой будем откладывать две точки на плоскости  и , такие, чтобы выполнялось условие:
#
#  и
#
# Проведём из точки  в точку  направленный отрезок :
#
# ![](./vectors/image3.png)
#
#
# Координатами отрезка  будет разница между соответствующими координатами конца и начала отрезка, а это и будет вектор :
#
# →Таким образом, любой вектор  размерности 2 можно интерпретировать как направленный отрезок, имеющий конец и начало.
#
# Любой отрезок, даже направленный, имеет длину. Длина вектора  обозначается как  и определяется как гипотенуза треугольника  по теореме Пифагора:
#
# * * *
#
# Давайте посмотрим конкретный пример с конкретными числами.
#
# Пусть есть вектор . Построим две точки  и  в системе координат  и соединим их направленным отрезком с направлением от точки  к точке . Тогда вектор  будет направленным отрезком из точки  в точку .
#
# Длина вектора  будет равна:
#
# ![](./vectors/image4.png)
#
#
# Почему мы выбираем именно точки  и ? Ведь можно построить вектор  и другими способами, например:
#
# Верно. Все предложенные комбинации точек  и  задают вектор .
#
# ![](./vectors/image5.png)
#
#
# Сколько комбинаций точек  и  можно придумать? Если подумать, бесконечное множество. Получается, существует бесконечное количество векторов ?
#
# И да, и нет. Если посмотреть на приведённый выше рисунок, можно заметить, что все векторы имеют одинаковую длину  , а также параллельны друг другу и имеют одно и то же направление. В этом случае говорят, что  **векторы сонаправлены и равны друг другу**. Тогда все векторы можно совместить в один с помощью параллельного переноса в какую-то точку на плоскости.
#
# В линейной алгебре в качестве такой точки принята точка начала системы координат . Таким образом, начало всех возможных векторов  переносится в точку  и геометрическая интерпретация вектора  размерности 2 обретёт новый смысл.
#
# Вектор  задаёт в прямоугольной системе координат   отрезок, направленный из начала системы  координат в точку с координатами .
#
# Сколько всего различных между собой векторов можно построить в системе координат ? Опять же — бесконечное множество! Мы можем провести сколько угодно векторов с началом в точке . На рисунке ниже представлено шесть таких векторов:
#
# ![](./vectors/image6.png)
#
#
# Множество всех возможных векторов  называют  **векторным пространством**. Говорят: вектор  принадлежит векторному пространству . Запись: .
#
# В свою очередь, каждая координата векторов  и  является действительным числом, то есть принадлежит множеству действительных чисел. В математике оно обозначается за . Запись: .
#
# Так как размерность вектора равна 2, то векторное пространство  является частью двухмерного пространства действительных чисел и обозначается как . Запись: .
#
# Отсюда: . Для краткости часто пишут: .
#
# Последняя запись «переводится» как «Задан вектор  размерности , такой, что его координаты являются действительными числами».
#
# Если перед нами вектор  размерностью , то он будет задавать в векторном пространстве  направленный отрезок с началом в точке  и концом в точке :
#
# ![](./vectors/image7.png)
#
#
# Длина трёхмерного вектора  определяется аналогично двухмерному:
#
# В общем случае вектор  размерностью  задаёт в векторном -мерном пространстве  направленный отрезок с началом в точке  и концом в точке .
#
# **Примечание.**  Для краткости точку  можно записать в виде вектора со всеми координатами, равными . Такой вектор называется  **нулевым вектором**  и обозначается как .
#
# Длина такого вектора  будет вычисляться так:
#
# Давайте отойдём от строгой математики и разберём, что собой представляет векторное пространство в нашей жизни.
#
# Вернёмся к примеру с арендой квартир. Пусть у нас есть четыре квартиры, которые характеризуются тремя признаками (арендная плата, площадь, число показов в день), представленными в таблице (привычный нам _DataFrame_):
#
# | **№**** квартиры **|** Арендная плата (тыс. руб.) **|** Площадь (кв. м) **|** Количество комнат **|** Этаж **|** Показов в день** |
# | --- | --- | --- | --- | --- | --- |
# | 1 | 65 | 50 | 3 | 5 | 8 |
# | 2 | 70 | 52 | 2 | 12 | 4 |
# | 3 | 120 | 80 | 1 | 10 | 5 |
# | 4 | 35 | 33 | 1 | 3 | 10 |
#
# Тогда каждую квартиру можно обозначить за вектор-строку .
#
# Если мы возьмём значения признаков, описывающих каждую квартиру, в качестве векторов , то получим четыре вектора следующего вида:
#
# **Примечание.**  Здесь первый индекс координаты обозначает номер вектора, а второй индекс — номер его координаты.
#
# Таким образом, у нас есть четыре вектора , которые принадлежат некоторому векторному пространству с размерностью .
#
# В общем случае квартир может быть больше, в пределе — бесконечное множество. Тогда векторное пространство  описывает множество всевозможных квартир, характеризующихся координатами-признаками, которые приведены в таблице.
#
# ### Задание 2.2
#
# 0 points possible (ungraded)
#
# Задан вектор
#
# **A**  Длина вектора  равна
#
# **B**  Угол между осью абсцисс и вектором  острый (меньше 90°)
#
# **C**  Угол между осью абсцисс и вектором  тупой (больше 90°)
#
# **D**  Длина вектора  равна
#
# верно
#
# **Ответ**
#
# Верно:
#
# **A**  Верно.
#
# **B**  Верно.
#
# Show answer
#
# Отправить
#
# Some problems have options such as save, reset, hints, or show answer. These options follow the Submit button.
#
# Отлично. Мы поняли, что из себя представляют вектор и векторное пространство. Давайте посмотрим, какие операции возможны с векторами.
